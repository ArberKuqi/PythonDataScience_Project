# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %%
ucl = pd.read_excel('UCL_playerstats_orig.xlsx')

# %%
ucl.columns
# Out:
# Index(['PlayerID', 'Player', 'Position', 'Age', 'Nationality', 'Team',
#        'Competitions', 'Phase', 'Phase_Tier', 'Value10^6', 'Jersey_Num',
#        'Rating', 'Goals', 'Assists', 'TopSpeed(km/h)', 'DistanceCovered(km)',
#        'Total_attempts', 'Dribbles', 'Passes_completed', 'Chances_Created',
#        'Balls_recovered', 'Tackles_Won', 'Tackles_Lost', 'Saves',
#        'Goals_Conceded', 'Clean_Sheets', 'MOTM_Awards', 'Minutes_played',
#        'Match_played', 'DNP'],
#       dtype='object')

# %%
features = [
    'Age', 'Position', 'Team',
    'Rating', 'Goals', 'Assists', 'Minutes_played', 'Chances_Created', 'Total_attempts'
]

X = ucl[features + ['Player']]
y = ucl['Value10^6']

# %% [markdown]
# #### 1️⃣ Zgjedhim veqorit(dmth features) dhe shtojm kolonen Player ne X

# %%
X
# Out:
#      Age    Position              Team  Rating  Goals  Assists  \
# 0     27    Defender             Milan    7.02      0        0
# 1     28  Midfielder             Inter    7.11      0        2
# 2     36     Forward         Barcelona    7.48     11        0
# 3     28     Forward         Barcelona    8.31     13        9
# 4     33    Defender      Liverpool FC    7.31      1        0
# ..   ...         ...               ...     ...    ...      ...
# 205   22     Forward  Shakhtar Donetsk    7.15      2        0
# 206   35  Midfielder            Lille     7.06      1        1
# 207   27  Midfielder         Juventus     7.41      0        0
# 208   26  Midfielder  Bayer Leverkusen    7.43      0        0
# 209   26    Defender           Bologna    7.01      1        0
#
#      Minutes_played  Chances_Created  Total_attempts          Player
# 0               861               12              17  Theo Hernandez
# 1               994               14              12  Nicolo Barella
# 2               985               11              34     Lewandowski
# 3              1225               39              52        Raphinha
# 4               840                2               4        Van Dijk
# ..              ...              ...             ...             ...
# 205             460                5              10           Kevin
# 206             388                7               9         Cabella
# 207             673                9               2       Locatelli
# 208             666                7              10        Palacios
# 209             531                0               3          Lucumi
#
# [210 rows x 10 columns]

# %% [markdown]
# #### 2️⃣ Bojm One-Hot Encoding, por ruajm emrin veqmas

# %%
X_encoded = pd.get_dummies(X.drop('Player', axis=1), drop_first=True)
player_names = X['Player']

# %%
X_encoded
# Out:
#      Age  Rating  Goals  Assists  Minutes_played  Chances_Created  \
# 0     27    7.02      0        0             861               12
# 1     28    7.11      0        2             994               14
# 2     36    7.48     11        0             985               11
# 3     28    8.31     13        9            1225               39
# 4     33    7.31      1        0             840                2
# ..   ...     ...    ...      ...             ...              ...
# 205   22    7.15      2        0             460                5
# 206   35    7.06      1        1             388                7
# 207   27    7.41      0        0             673                9
# 208   26    7.43      0        0             666                7
# 209   26    7.01      1        0             531                0
#
#      Total_attempts  Position_Forward  Position_Goalkeeper  \
# 0                17             False                False
# 1                12             False                False
# 2                34              True                False
# 3                52              True                False
# 4                 4             False                False
# ..              ...               ...                  ...
# 205              10              True                False
# 206               9             False                False
# 207               2             False                False
# 208              10             False                False
# 209               3             False                False
#
#      Position_Midfielder  ...  Team_Milan  Team_Monaco  Team_PSV Eindhoven  \
# 0                  False  ...        True        False               False
# 1                   True  ...       False        False               False
# 2                  False  ...       False        False               False
# 3                  False  ...       False        False               False
# 4                  False  ...       False        False               False
# ..                   ...  ...         ...          ...                 ...
# 205                False  ...       False        False               False
# 206                 True  ...       False        False               False
# 207                 True  ...       False        False               False
# 208                 True  ...       False        False               False
# 209                False  ...       False        False               False
#
#      Team_Paris SG  Team_Real Madrid  Team_Real Madrid   \
# 0            False             False              False
# 1            False             False              False
# 2            False             False              False
# 3            False             False              False
# 4            False             False              False
# ..             ...               ...                ...
# 205          False             False              False
# 206          False             False              False
# 207          False             False              False
# 208          False             False              False
# 209          False             False              False
#
#      Team_Shakhtar Donetsk  Team_Sporting CP  Team_Sturm Graz  \
# 0                    False             False            False
# 1                    False             False            False
# 2                    False             False            False
# 3                    False             False            False
# 4                    False             False            False
# ..                     ...               ...              ...
# 205                   True             False            False
# 206                  False             False            False
# 207                  False             False            False
# 208                  False             False            False
# 209                  False             False            False
#
#      Team_VfB Stuttgart
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ..                  ...
# 205               False
# 206               False
# 207               False
# 208               False
# 209               False
#
# [210 rows x 41 columns]

# %% [markdown]
# #### 3️⃣ Train/test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test, names_train, names_test = train_test_split(X_encoded, y, player_names, test_size=0.4, random_state=42)

# %% [markdown]
# #### 4️⃣ Trajnojm modelin Linear Regression dhe parashikojm

# %%
modeli = LinearRegression()
modeli.fit(X_train, y_train)
parashiku = modeli.predict(X_test)

# %% [markdown]
# #### 5️⃣ Krijojm DataFrame per paraqitjen finale

# %%
results_ucl = pd.DataFrame({
    'Player': names_test.values,
    'Actual Value': y_test.values,
    'Predicted Value': parashiku.astype(int)
})

# %%
results_ucl
# Out:
#               Player  Actual Value  Predicted Value
# 0         Martinelli          55.0              105
# 1           Mignolet           1.0              -50
# 2        Rafael Leao          75.0               47
# 3        Gravenberch          30.0               81
# 4   Lautaro Martinez         100.0               57
# ..               ...           ...              ...
# 79    Julian Alvarez          90.0               52
# 80    Quinten Timber          32.0                2
# 81          Emre Can           7.0                0
# 82             Singo          25.0               18
# 83              Kuhn          12.0               32
#
# [84 rows x 3 columns]

# %%
top_players = results_ucl.sort_values(by='Actual Value', ascending=False).head(25)

fig, ax = plt.subplots(figsize=(10, 8))
ax.axis('off')
table = ax.table(
    cellText=top_players.values,
    colLabels=top_players.columns,
    loc='center',
    cellLoc='center'
)
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.2)
plt.title("Actual vs Predicted Value for UCL Players", fontsize=14)
plt.show()
