# %%
import pandas as pd
import plotly as px
import numpy as np

# %%
ucl = pd.read_excel('UCL_playerstats_orig.xlsx')

# %%
ucl['Competitions'] = ucl['Competitions'].str.strip()

# %%
ucl['Team'] = ucl['Team'].str.strip()

# %%
ucl.head()
# Out:
#    PlayerID          Player    Position  Age  Nationality          Team  \
# 0         1  Theo Hernandez    Defender   27       France         Milan
# 1         2  Nicolo Barella  Midfielder   28        Italy         Inter
# 2         3     Lewandowski     Forward   36       Poland     Barcelona
# 3         4        Raphinha     Forward   28       Brazil     Barcelona
# 4         5        Van Dijk    Defender   33  Netherlands  Liverpool FC
#
#      Competitions           Phase Phase_Tier  Value10^6  ...  Balls_recovered  \
# 0         Serie A  Knockout_phase          D       40.0  ...               53
# 1         Serie A           Final          S       80.0  ...               32
# 2         La Liga    Semi_finals           A       15.0  ...               11
# 3         La Liga    Semi_finals           A       80.0  ...               18
# 4  Premier League         Round16          C       50.0  ...               51
#
# ...

# %%
result_players = (
    ucl.groupby("Nationality")['Player']
    .count()
    .reset_index()
    .rename(columns={"Nationality": "Country", "Name": "Player"})
    .sort_values(by="Player", ascending=False)
    .head(10)
)

result_players
# Out:
#         Country  Player
# 14       France      24
# 26  Netherlands      18
# 37        Spain      16
# 16      Germany      16
# 6        Brazil      15
# 21        Italy      11
# 13      England      11
# 1     Argentina      10
# 4       Belgium       9
# 30     Portugal       9

# %% [markdown]
# #### Removing Column

# %%
ucl.drop('Key_Passes',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ucl.drop('Key_Passes',axis=1)
#
# File ~\Desktop\Python Data Science\ProjectUCL\.venv\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %% [markdown]
# #### Creating new Column

# %%
ucl['Tackles'] = ucl['Tackles_Won'] + ucl['Tackles_Lost']

# %%
ucl
# Out:
#      PlayerID          Player    Position  Age  Nationality              Team  \
# 0           1  Theo Hernandez    Defender   27       France             Milan
# 1           2  Nicolo Barella  Midfielder   28        Italy             Inter
# 2           3     Lewandowski     Forward   36       Poland         Barcelona
# 3           4        Raphinha     Forward   28       Brazil         Barcelona
# 4           5        Van Dijk    Defender   33  Netherlands      Liverpool FC
# ..        ...             ...         ...  ...          ...               ...
# 205       206           Kevin     Forward   22       Brazil  Shakhtar Donetsk
# 206       207         Cabella  Midfielder   35       France             Lille
# 207       208       Locatelli  Midfielder   27        Italy          Juventus
# 208       209        Palacios  Midfielder   26    Argentina  Bayer Leverkusen
# 209       210          Lucumi    Defender   26     Colombia           Bologna
#
# ...

# %% [markdown]
# #### How many rows and columns are in datafram UCL

# %%
print('Len of Columns :', len(ucl.columns))
print('Len of Rows:',len(ucl.index))
# Out:
# Len of Columns : 31
# Len of Rows: 210

# %% [markdown]
# #### What is the team of Raphinha ? Note: Use all caps, otherwise you may get an answer that doesn't match up (there is also a lowercase Raphinha)

# %%
ucl[ucl['Player'] == 'Raphinha']['Team']
# Out:
# 3    Barcelona
# Name: Team, dtype: object

# %% [markdown]
# #### Player with the highest value in champions league season 2025 base in Transfermarkt

# %%
ucl[ucl['Value10^6'] == ucl['Value10^6'].max()][['PlayerID','Player','Value10^6']]
# Out:
#     PlayerID       Player  Value10^6
# 37        38  Vinicius Jr      200.0

# %%
# ucl.loc[]
highest_value = ucl.loc[ucl['Value10^6'].idxmax()]

highest_value
# Out:
# PlayerID                            38
# Player                     Vinicius Jr
# Position                       Forward
# Age                                 24
# Nationality                     Brazil
# Team                       Real Madrid
# Competitions                   La Liga
# Phase                  Quarter_finals
# Phase_Tier                           B
# Value10^6                        200.0
# Jersey_Num                           7
# Rating                            7.79
# Goals                                8
# Assists                              3
# TopSpeed(km/h)                    35.5
# DistanceCovered(km)              118.9
# Total_attempts                      42
# Dribbles                            82
# Passes_completed                   269
# Chances_Created                     23
# Key_Passes                          23
# Balls_recovered                     20
# Tackles_Won                          3
# Tackles_Lost                        11
# ...

# %% [markdown]
# #### How many unique team  are there?

# %%
len(ucl['Team'].unique())
# Out:
# 31

# %%
ucl['Team'].value_counts().reset_index(name='players_num')
# Out:
#                 Team  players_num
# 0              Inter           13
# 1          Barcelona           12
# 2         Arsenal FC           12
# 3           Paris SG           12
# 4        Real Madrid           11
# 5       BVB Dortmund           11
# 6      PSV Eindhoven           10
# 7      Bayern Munich           10
# 8       Liverpool FC           10
# 9            Benfica            9
# 10       Atalanta BC            9
# 11       Aston Villa            8
# 12   Atletico Madrid            8
# 13  Bayer Leverkusen            7
# 14             Milan            7
# 15            Monaco            7
# 16   Manchester City            7
# 17            Celtic            6
# 18             Lille            6
# 19       Sporting CP            6
# 20       Club Brugge            5
# 21          Juventus            5
# 22         Feyenoord            4
# 23           Bologna            4
# 24  Shakhtar Donetsk            3
# 25             Brest            2
# ...

# %%
all_goals = ucl.sum()['Goals']
all_assists = ucl.sum()['Assists']
all_saves = ucl.sum()['Saves']

# %%
print(f'All goals Champions League: {all_goals}')
print(f'All assists Champions League: {all_assists}')
print(f'All saves Champions League: {all_saves}')
# Out:
# All goals Champions League: 382
# All assists Champions League: 284
# All saves Champions League: 678
